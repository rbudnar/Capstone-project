# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display # Allows the use of display() for DataFrames
import seaborn as sb
# %matplotlib inline

import keras
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Input, Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Add, Concatenate
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint

# %%
## loading from dataframe https://medium.com/@vijayabhaskar96/tutorial-on-keras-flow-from-dataframe-1fd4493d237c

def generate_dataframe_from_csv(path):
    data = pd.read_csv(path)
    columns = (data.apply(lambda r: pd.Series(gen_image_paths(r)), axis=1)
        .stack()
        .rename("img_path")
        .reset_index(level=1, drop=True))
    data["sirna"] = data["sirna"].apply(lambda s: str(s))
    return data.join(columns).reset_index(drop=True)

def gen_image_paths(row):
    path_root = f"train/{row['experiment']}/Plate{row['plate']}/{row['well']}"
    return [f"{path_root}_s{site}_w{image}.png" for site in range(1, 3) for image in range(1,7)]

# %%
# from main import generate_dataframe_from_csv

df = generate_dataframe_from_csv("train.csv")
display(df)
# Out:
#                id_code experiment  plate well sirna  \
# 0       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 1       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 2       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 3       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 4       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 5       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 6       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 7       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 8       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 9       HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 10      HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 11      HEPG2-01_1_B03   HEPG2-01      1  B03   513
# 12      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 13      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 14      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 15      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 16      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 17      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 18      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 19      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 20      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 21      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 22      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 23      HEPG2-01_1_B04   HEPG2-01      1  B04   840
# 24      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# 25      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# 26      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# 27      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# 28      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# 29      HEPG2-01_1_B05   HEPG2-01      1  B05  1020
# ...                ...        ...    ...  ...   ...
# 438150   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438151   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438152   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438153   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438154   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438155   U2OS-03_4_O21    U2OS-03      4  O21   824
# 438156   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438157   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438158   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438159   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438160   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438161   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438162   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438163   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438164   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438165   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438166   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438167   U2OS-03_4_O22    U2OS-03      4  O22   328
# 438168   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438169   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438170   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438171   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438172   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438173   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438174   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438175   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438176   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438177   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438178   U2OS-03_4_O23    U2OS-03      4  O23   509
# 438179   U2OS-03_4_O23    U2OS-03      4  O23   509
#
#                                    img_path
# 0       train/HEPG2-01/Plate1/B03_s1_w1.png
# 1       train/HEPG2-01/Plate1/B03_s1_w2.png
# 2       train/HEPG2-01/Plate1/B03_s1_w3.png
# 3       train/HEPG2-01/Plate1/B03_s1_w4.png
# 4       train/HEPG2-01/Plate1/B03_s1_w5.png
# 5       train/HEPG2-01/Plate1/B03_s1_w6.png
# 6       train/HEPG2-01/Plate1/B03_s2_w1.png
# 7       train/HEPG2-01/Plate1/B03_s2_w2.png
# 8       train/HEPG2-01/Plate1/B03_s2_w3.png
# 9       train/HEPG2-01/Plate1/B03_s2_w4.png
# 10      train/HEPG2-01/Plate1/B03_s2_w5.png
# 11      train/HEPG2-01/Plate1/B03_s2_w6.png
# 12      train/HEPG2-01/Plate1/B04_s1_w1.png
# 13      train/HEPG2-01/Plate1/B04_s1_w2.png
# 14      train/HEPG2-01/Plate1/B04_s1_w3.png
# 15      train/HEPG2-01/Plate1/B04_s1_w4.png
# 16      train/HEPG2-01/Plate1/B04_s1_w5.png
# 17      train/HEPG2-01/Plate1/B04_s1_w6.png
# 18      train/HEPG2-01/Plate1/B04_s2_w1.png
# 19      train/HEPG2-01/Plate1/B04_s2_w2.png
# 20      train/HEPG2-01/Plate1/B04_s2_w3.png
# 21      train/HEPG2-01/Plate1/B04_s2_w4.png
# 22      train/HEPG2-01/Plate1/B04_s2_w5.png
# 23      train/HEPG2-01/Plate1/B04_s2_w6.png
# 24      train/HEPG2-01/Plate1/B05_s1_w1.png
# 25      train/HEPG2-01/Plate1/B05_s1_w2.png
# 26      train/HEPG2-01/Plate1/B05_s1_w3.png
# 27      train/HEPG2-01/Plate1/B05_s1_w4.png
# 28      train/HEPG2-01/Plate1/B05_s1_w5.png
# 29      train/HEPG2-01/Plate1/B05_s1_w6.png
# ...                                     ...
# 438150   train/U2OS-03/Plate4/O21_s2_w1.png
# 438151   train/U2OS-03/Plate4/O21_s2_w2.png
# 438152   train/U2OS-03/Plate4/O21_s2_w3.png
# 438153   train/U2OS-03/Plate4/O21_s2_w4.png
# 438154   train/U2OS-03/Plate4/O21_s2_w5.png
# 438155   train/U2OS-03/Plate4/O21_s2_w6.png
# 438156   train/U2OS-03/Plate4/O22_s1_w1.png
# 438157   train/U2OS-03/Plate4/O22_s1_w2.png
# 438158   train/U2OS-03/Plate4/O22_s1_w3.png
# 438159   train/U2OS-03/Plate4/O22_s1_w4.png
# 438160   train/U2OS-03/Plate4/O22_s1_w5.png
# 438161   train/U2OS-03/Plate4/O22_s1_w6.png
# 438162   train/U2OS-03/Plate4/O22_s2_w1.png
# 438163   train/U2OS-03/Plate4/O22_s2_w2.png
# 438164   train/U2OS-03/Plate4/O22_s2_w3.png
# 438165   train/U2OS-03/Plate4/O22_s2_w4.png
# 438166   train/U2OS-03/Plate4/O22_s2_w5.png
# 438167   train/U2OS-03/Plate4/O22_s2_w6.png
# 438168   train/U2OS-03/Plate4/O23_s1_w1.png
# 438169   train/U2OS-03/Plate4/O23_s1_w2.png
# 438170   train/U2OS-03/Plate4/O23_s1_w3.png
# 438171   train/U2OS-03/Plate4/O23_s1_w4.png
# 438172   train/U2OS-03/Plate4/O23_s1_w5.png
# 438173   train/U2OS-03/Plate4/O23_s1_w6.png
# 438174   train/U2OS-03/Plate4/O23_s2_w1.png
# 438175   train/U2OS-03/Plate4/O23_s2_w2.png
# 438176   train/U2OS-03/Plate4/O23_s2_w3.png
# 438177   train/U2OS-03/Plate4/O23_s2_w4.png
# 438178   train/U2OS-03/Plate4/O23_s2_w5.png
# 438179   train/U2OS-03/Plate4/O23_s2_w6.png
#
# [438180 rows x 6 columns]

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True,
        validation_split=0.25)

train_generator = train_datagen.flow_from_dataframe(
        df,
        directory="./",
        x_col="img_path",
        y_col="sirna",
        target_size=(224, 224),
        batch_size=32,
        subset="training",
        class_mode='categorical')

valid_generator = train_datagen.flow_from_dataframe(
        df,
        directory="./",
        x_col="img_path",
        y_col="sirna",
        target_size=(224, 224),
        batch_size=32,
        subset="validation",
        class_mode='categorical')
# Out:
# Found 328635 images belonging to 1108 classes.
# Found 109545 images belonging to 1108 classes.

# %%
# https://www.pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/
from keras.backend import concatenate

# def build_cnn_layer(shape=(150,150,3,)):
#     inputlayer = Input(shape=shape, name="inputlayer")
#     x = Conv2D(filters=32, kernel_size=3, padding='same')(inputlayer)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)
#     x = MaxPooling2D(pool_size=4)(x)
#     x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
# #     model = Model(inputs=inputlayer, outputs=x)
#     return x #model

# def build_sequential_layer(previous_layers):
# #     combined = concatenate([x.output for x in previous_layers])
# #     combined = BatchNormalization()(combined)
# #     combined = Activation("relu")(combined)
# #     combined = Flatten()(combined)
# #     combined = Dense(1108, activation="softmax")(combined)
# #     return combined
#     combined = Add()(previous_layers)
# #     combined = BatchNormalization()(combined)
#     combined = Activation("relu")(combined)
# #     combined = Flatten()(combined)
#     combined = Dense(1108, activation="softmax")(combined)
#     return combined

# def build_model():
#     cnn_layers = []
#     for i in range(0,6):
#         layer = build_cnn_layer()
#         print(layer)
#         cnn_layers.append(layer)
    
# #     model = Model(inputs=[x.input for x in cnn_layers], outputs=build_sequential_layer(cnn_layers))
#     model = Model(inputs=cnn_layers, outputs=build_sequential_layer(cnn_layers))
#     optimizer = optimizers.Adam()    
#     model.compile(optimizer, loss='categorical_crossentropy')
#     return model


def build_cnn_layer(i, shape=(150,150,3,)):
    name = f"inputlayer_{i}"
    inputlayer = Input(shape=shape, name=name)
    x = Conv2D(filters=32, kernel_size=3, padding='same')(inputlayer)
    x = BatchNormalization(name=f"bn_cnn_{i}")(x)
    x = Activation("relu")(x)
    x = MaxPooling2D(pool_size=4)(x)
    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    model = Model(inputs=inputlayer, outputs=x)
    return model

def build_sequential_layer(previous_layers):
    combined = Concatenate()([x.output for x in previous_layers])
    combined = BatchNormalization(name="batch_norm_1")(combined)
#     combined = Activation("relu", name="act_layer")(combined)
#     combined = Flatten(name="flattener")(combined)
#     z = Dense(2000, activation="softmax")(combined)
    z = Dense(1108, activation="softmax")(combined)
    return z
#     combined = Add()(previous_layers)
#     combined = BatchNormalization()(combined)
#     combined = Activation("relu")(combined)
#     combined = Flatten()(combined)
#     combined = Dense(1108, activation="softmax")(combined)
#     return combined

def build_model():
    cnn_layers = []
    for i in range(0,6):
        layer = build_cnn_layer(i)
        cnn_layers.append(layer)

    output_layer = build_sequential_layer(cnn_layers)
    print(output_layer)
    model = Model(inputs=[x.input for x in cnn_layers], outputs=output_layer)
#     model = Model(inputs=cnn_layers, outputs=build_sequential_layer(cnn_layers))
    optimizer = optimizers.Adam()    
    model.compile(optimizer, loss='categorical_crossentropy')
    return model

# %%
model = build_model()
model.summary()
# Out:
# Tensor("dense_15/truediv:0", shape=(?, 37, 37, 1108), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputlayer_0 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# inputlayer_1 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# inputlayer_2 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# inputlayer_3 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# inputlayer_4 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# inputlayer_5 (InputLayer)       (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_0[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_1[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_2[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_3[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_4[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 150, 150, 32) 896         inputlayer_5[0][0]
# __________________________________________________________________________________________________
# bn_cnn_0 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_217[0][0]
# __________________________________________________________________________________________________
# bn_cnn_1 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_219[0][0]
# __________________________________________________________________________________________________
# bn_cnn_2 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_221[0][0]
# __________________________________________________________________________________________________
# bn_cnn_3 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_223[0][0]
# __________________________________________________________________________________________________
# bn_cnn_4 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_225[0][0]
# __________________________________________________________________________________________________
# bn_cnn_5 (BatchNormalization)   (None, 150, 150, 32) 128         conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 150, 150, 32) 0           bn_cnn_0[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 150, 150, 32) 0           bn_cnn_1[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 150, 150, 32) 0           bn_cnn_2[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 150, 150, 32) 0           bn_cnn_3[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 150, 150, 32) 0           bn_cnn_4[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 150, 150, 32) 0           bn_cnn_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_109 (MaxPooling2D (None, 37, 37, 32)   0           activation_112[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_110 (MaxPooling2D (None, 37, 37, 32)   0           activation_113[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_111 (MaxPooling2D (None, 37, 37, 32)   0           activation_114[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_112 (MaxPooling2D (None, 37, 37, 32)   0           activation_115[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_113 (MaxPooling2D (None, 37, 37, 32)   0           activation_116[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_114 (MaxPooling2D (None, 37, 37, 32)   0           activation_117[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_111[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 37, 37, 64)   18496       max_pooling2d_114[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 37, 37, 384)  0           conv2d_218[0][0]
#                                                                  conv2d_220[0][0]
#                                                                  conv2d_222[0][0]
#                                                                  conv2d_224[0][0]
#                                                                  conv2d_226[0][0]
#                                                                  conv2d_228[0][0]
# __________________________________________________________________________________________________
# batch_norm_1 (BatchNormalizatio (None, 37, 37, 384)  1536        concatenate_11[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 37, 37, 1108) 426580      batch_norm_1[0][0]
# ==================================================================================================
# Total params: 545,236
# Trainable params: 544,084
# Non-trainable params: 1,152
# __________________________________________________________________________________________________

# %%
## Simple model
# model = Sequential([
#     Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(150, 150, 3)),
#     MaxPooling2D(pool_size=2),
#     Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'),
#     MaxPooling2D(pool_size=2),
#     Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'),
#     MaxPooling2D(pool_size=2),
#     Flatten(),
#     Dense(300, activation="relu"),
#     Dropout(.4),
#     Dense(1108, activation="softmax")    
# ])
## Model from dog project
model = Sequential([
    BatchNormalization(input_shape=(224, 224, 3)),
    Conv2D(filters=32, kernel_size=3, padding='same'),
    BatchNormalization(),
    Activation("relu"),
    MaxPooling2D(pool_size=4),
    Conv2D(filters=64, kernel_size=3, padding='same'),
    BatchNormalization(),
    Activation("relu"),
    Flatten(),
    Dense(1108, activation="softmax") 
])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_4 (Batch (None, 224, 224, 3)       12
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# activation_3 (Activation)    (None, 224, 224, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# activation_4 (Activation)    (None, 56, 56, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 200704)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1108)              222381140
# =================================================================
# Total params: 222,400,928
# Trainable params: 222,400,730
# Non-trainable params: 198
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size

# %%
print(STEP_SIZE_TRAIN, STEP_SIZE_VALID)
# Out:
# 10269 3423

# %%
epochs = 10

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit_generator(train_generator, 
                    steps_per_epoch=15,
                    validation_data=valid_generator,
                    validation_steps=15,                    
                    epochs=epochs, callbacks=[checkpointer], verbose=1)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 75s 5s/step - loss: 15.5084 - acc: 0.0021 - val_loss: 16.0845 - val_acc: 0.0021
#
# Epoch 00001: val_loss improved from inf to 16.08452, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/10
# 15/15 [==============================] - 67s 4s/step - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss did not improve from 16.08452
# Epoch 3/10
# 15/15 [==============================] - 69s 5s/step - loss: 16.0442 - acc: 0.0042 - val_loss: 16.0845 - val_acc: 0.0021
#
# Epoch 00003: val_loss did not improve from 16.08452
# Epoch 4/10
# 15/15 [==============================] - 67s 4s/step - loss: 16.0845 - acc: 0.0021 - val_loss: 16.0845 - val_acc: 0.0021
#
# Epoch 00004: val_loss did not improve from 16.08452
# Epoch 5/10
# 15/15 [==============================] - 67s 4s/step - loss: 16.0853 - acc: 0.0021 - val_loss: 16.1181 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss did not improve from 16.08452
# Epoch 6/10
# 15/15 [==============================] - 66s 4s/step - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss did not improve from 16.08452
# Epoch 7/10
# 15/15 [==============================] - 66s 4s/step - loss: 16.0509 - acc: 0.0042 - val_loss: 16.0845 - val_acc: 0.0021
#
# Epoch 00007: val_loss did not improve from 16.08452
# Epoch 8/10
# 15/15 [==============================] - 66s 4s/step - loss: 16.0853 - acc: 0.0021 - val_loss: 16.1181 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss did not improve from 16.08452
# Epoch 9/10
# 15/15 [==============================] - 68s 5s/step - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.1181 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss did not improve from 16.08452
# Epoch 10/10
# 15/15 [==============================] - 67s 4s/step - loss: 16.1181 - acc: 0.0000e+00 - val_loss: 16.0845 - val_acc: 0.0021
#
# Epoch 00010: val_loss did not improve from 16.08452
